# %%
import pandas as pd
import csv
import os

# %%
cassandra = pd.read_csv(os.getcwd() + '/cassandra-tsload.txt', header=None, index_col=0, sep=",", quoting=csv.QUOTE_NONE)

# %%
cassandra
# Out:
#                                                          1  \
# 0
# [OVERALL]                                      RunTime(ms)
# [OVERALL]                              Throughput(ops/sec)
# [TOTAL_GCS_PS_Scavenge]                              Count
# [TOTAL_GC_TIME_PS_Scavenge]                       Time(ms)
# [TOTAL_GC_TIME_%_PS_Scavenge]                      Time(%)
# [TOTAL_GCS_PS_MarkSweep]                             Count
# [TOTAL_GC_TIME_PS_MarkSweep]                      Time(ms)
# [TOTAL_GC_TIME_%_PS_MarkSweep]                     Time(%)
# [TOTAL_GCs]                                          Count
# [TOTAL_GC_TIME]                                   Time(ms)
# [TOTAL_GC_TIME_%]                                  Time(%)
# [CLEANUP]                                       Operations
# [CLEANUP]                               AverageLatency(us)
# [CLEANUP]                                   MinLatency(us)
# [CLEANUP]                                   MaxLatency(us)
# ...

# %%
hbase = pd.read_csv(os.getcwd() + '/hbase-tsload.txt', header=None, index_col=0, sep=",", quoting=csv.QUOTE_NONE)

# %%
hbase
# Out:
#                                                          1             2
# 0
# [OVERALL]                                      RunTime(ms)  3.088780e+05
# [OVERALL]                              Throughput(ops/sec)  4.773924e+03
# [TOTAL_GCS_PS_Scavenge]                              Count  5.860000e+02
# [TOTAL_GC_TIME_PS_Scavenge]                       Time(ms)  8.060000e+02
# [TOTAL_GC_TIME_%_PS_Scavenge]                      Time(%)  2.609445e-01
# [TOTAL_GCS_PS_MarkSweep]                             Count  1.000000e+00
# [TOTAL_GC_TIME_PS_MarkSweep]                      Time(ms)  2.100000e+01
# [TOTAL_GC_TIME_%_PS_MarkSweep]                     Time(%)  6.798801e-03
# [TOTAL_GCs]                                          Count  5.870000e+02
# [TOTAL_GC_TIME]                                   Time(ms)  8.270000e+02
# [TOTAL_GC_TIME_%]                                  Time(%)  2.677433e-01
# [CLEANUP]                                       Operations  2.000000e+00
# ...
